# %%
import numpy as np
import pandas as pd
import sys
sys.path.append("..")
from DataLoader import *
from postprocessing import *
from preprocessing import *
import matplotlib.pyplot as plt

# %%
df_test = pd.read_csv('sample_submission.csv')
test_dataset = CarDataset(df_test, root_dir = 'test')

# %%
train_images_dir = 'test_images/{}.jpg'
pred = np.load('../inferences/b2_fold0.npy')

for idx in [15,20,25]:
    img, mask, regr = test_dataset.__getitem__(idx)
    
    coords_pred = extract_coords(pred[idx], mode = 'ss', thr = 0.15)
    img = imread(train_images_dir.format(df_test['ImageId'].iloc[idx]))
    
    fig, axes = plt.subplots(1, 1, figsize=(14,14))
    axes.set_title('Prediction')
    axes.imshow(visualize(img, coords_pred))
    plt.show()
